# %% [markdown]
# Data Abstraction in Python
# Last Updated : 19 Mar, 2026
# Data abstraction means showing only the essential features and hiding the complex internal details. In Python, abstraction is used to hide the implementation details from the user and expose only necessary parts, making the code simpler and easier to interact with.
#
# Real Life Example: In a graphics software, multiple shapes are available such as Circle, Rectangle and Triangle. All shapes share common data and support the same set of actions, but the internal details are hidden:
#
# Common data: name, color, border thickness, fill style.
# Common actions: draw(), resize(), getArea().
# Each shape implements these actions differently Circle uses radius, Rectangle uses length and width and Triangle uses base and height.
# The software only knows that a shape can be drawn and its area can be calculated. How the shape is drawn or how the area is calculated is hidden.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 class B(A):
#       9     pass
# ---> 11 b = B()
#
# TypeError: Can't instantiate abstract class B without an implementation for abstract method 'test'

# %% [markdown]
# What is an Abstract Class?
#
# 👉 An abstract class is a class that:
#
# Cannot be instantiated (no object can be created)
# Contains abstract methods (methods without implementation)
# Acts as a blueprint for child classes
#
# What is an Abstract Method?
#
# 👉 A method that:
#
# Has no body (no implementation)
# Must be implemented by child classes

# %%
from abc import ABC, abstractmethod

class Machine(ABC):
    @abstractmethod
    def process(self):
        pass


ma= Machine()
ma.process()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       4     @abstractmethod
#       5     def process(self):
#       6         pass
# ----> 9 ma= Machine()
#      10 ma.process()
#
# TypeError: Can't instantiate abstract class Machine without an implementation for abstract method 'process'

# %% [markdown]
# Why Use Abstract Class?
#
# 👉 To force child classes to implement certain methods

# %%
## Real world examples

from abc import ABC, abstractmethod

class Payment(ABC):
    @abstractmethod
    def pay(self, amount):

        pass


class CreditCard(Payment):
    
    def pay(self, amount):
        print("Paid_amount:",amount)



cs=CreditCard()
cs.pay(20)
# Out:
# Paid_amoutn: 20

# %% [markdown]
# When to Use Abstract Class
#
# Use when:
#
# ✔ You want to enforce structure
# ✔ You have multiple implementations
# ✔ You want consistency
#
# 🚫 When NOT to Use
#
# ❌ If only one implementation exists
# ❌ If no need to enforce structure
