# %%
import threading , time



def calculate(seconds):
    print(f"Executing in {seconds} seconds")



start= time.perf_counter()
calculate(4)
calculate(3)
calculate(2)

end = time.perf_counter()




print("noraml calling",end-start)

t1=threading.Thread(target=calculate, args=4)
t2=threading.Thread(target=calculate, args=2)
t3 =
# Out:
# Executing in 4 seconds
# Executing in 3 seconds
# Executing in 2 seconds
# 0.0009221000073011965
